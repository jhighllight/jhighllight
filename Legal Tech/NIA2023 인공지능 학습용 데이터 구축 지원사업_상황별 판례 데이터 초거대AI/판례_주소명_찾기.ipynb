# %%
#시군구 순서대로 출력

import pandas as pd
import re

def find_korean_addresses(text):
    """
    주어진 텍스트에서 한국 주소 형식에 맞는 문자열을 찾습니다.

    :param text: 검색할 전체 텍스트
    :return: 찾은 주소 목록
    """
    address_pattern = r'([가-힣]+(?:시|도)\s?[가-힣]+(?:구|군)?\s?[가-힣]+(?:동|면|리)\s?\d+(?:-\d+)?)'
    text = str(text)
    found_addresses = re.findall(address_pattern, text)
    return found_addresses


def extract_addresses_from_csv(file_path):
    """
    CSV 파일에서 A열과 B열을 읽고, B열의 텍스트 내에서 한국 주소를 찾아 A열의 판례일련번호와 연결합니다.

    :param file_path: CSV 파일의 경로
    :return: 판례일련번호와 찾은 주소 목록
    """
    df = pd.read_csv(file_path)
    df['Found_Addresses'] = df['판례내용'].apply(find_korean_addresses)

    return df[df['Found_Addresses'].map(lambda d: len(d) > 0)][['판례일련번호', 'Found_Addresses']]

# CSV 파일 경로
csv_file_path = '/content/비실명화_형사.csv'  # 여기에 실제 파일 경로를 입력하세요.

# CSV 파일에서 주소 추출 및 판례일련번호와 연결
address_data = extract_addresses_from_csv(csv_file_path)

# 결과 출력
for index, row in address_data.iterrows():
    print(f"판례일련번호: {row['판례일련번호']}, 찾은 주소: {row['Found_Addresses']}")
# Out:
# 판례일련번호: 70048.0, 찾은 주소: ['전주시 덕진구 인후동 1', '전주시 덕진구 인후동 1']
# 판례일련번호: 70075.0, 찾은 주소: ['양산시 북정동 552']
# 판례일련번호: 70188.0, 찾은 주소: ['광양시 황금동 200']
# 판례일련번호: 70812.0, 찾은 주소: ['원주시 명륜동 459', '원주시 명륜동 459']
# 판례일련번호: 70813.0, 찾은 주소: ['강릉시 성남동 110-5']
# 판례일련번호: 70885.0, 찾은 주소: ['청주시 흥덕구 분평동 1224', '청주시 분평동 1224', '청주시 분평동 1224']
# 판례일련번호: 70907.0, 찾은 주소: ['영천시 고경면 해선리 317-9']
# 판례일련번호: 71247.0, 찾은 주소: ['보령시 동대동 1865']
# 판례일련번호: 71248.0, 찾은 주소: ['안산시 고잔동 437', '안산시 고잔동 537']
# 판례일련번호: 71249.0, 찾은 주소: ['강릉시 사천면 415', '강릉시 사천면 415']
# 판례일련번호: 71536.0, 찾은 주소: ['수원시 장안구 화서동 650']
# 판례일련번호: 71564.0, 찾은 주소: ['상주시 낙동면 구잠리 222']
# 판례일련번호: 71565.0, 찾은 주소: ['성남시 중원구 상대원동 279-1']
# 판례일련번호: 76090.0, 찾은 주소: ['송탄시 서정동 239']
# 판례일련번호: 76095.0, 찾은 주소: ['전주시 인후동 1']
# 판례일련번호: 76262.0, 찾은 주소: ['안양시 박달동 68']
# 판례일련번호: 76269.0, 찾은 주소: ['부천시 삼정동 272']
# 판례일련번호: 76441.0, 찾은 주소: ['대구시 서구 내동1']
# 판례일련번호: 76454.0, 찾은 주소: ['구미시 공단동 2', '구미시 공당동 2', '구미시 공단동 2']
# 판례일련번호: 76536.0, 찾은 주소: ['송탄시 장당동 390', '다시 같은시 이충동 459']
# 판례일련번호: 76541.0, 찾은 주소: ['부천시 소사동 93', '부천시 소사동 93']
# 판례일련번호: 76548.0, 찾은 주소: ['서울시 관악구 신림동 112', '수원시 신풍동 305']
# 판례일련번호: 76549.0, 찾은 주소: ['강릉시 명주동 4', '강릉시 명주동 4']
# 판례일련번호: 76700.0, 찾은 주소: ['황해도 해주군 용당리 242']
# 판례일련번호: 76712.0, 찾은 주소: ['부천시 소사동 294']
# 판례일련번호: 77089.0, 찾은 주소: ['마산시 상남동 136']
# 판례일련번호: 80617.0, 찾은 주소: ['남양주시 진접읍 장현리 17']
# 판례일련번호: 80753.0, 찾은 주소: ['남양주시 수동면 수산리 217']
# 판례일련번호: 80869.0, 찾은 주소: ['고양시 일산구 주엽동 17']
# 판례일련번호: 81776.0, 찾은 주소: ['고양시 일산구 탄현동 1249']
# 판례일련번호: 82771.0, 찾은 주소: ['부천시 오정구 여월동 6-1']
# 판례일련번호: 82931.0, 찾은 주소: ['포항시 북구 동빈동 1']
# 판례일련번호: 83940.0, 찾은 주소: ['성남시 분당구 서현동 91']

# %%
#시 제외하고, 순서대로 출력

import pandas as pd
import re

def find_korean_addresses(text):
    """
    주어진 텍스트에서 한국 주소 형식에 맞는 문자열을 찾습니다.

    :param text: 검색할 전체 텍스트
    :return: 찾은 주소 목록
    """
    address_pattern = r'([가-힣]+(?:구|군)\s?[가-힣]+(?:동|면|리)\s?\d+(?:-\d+)?)'
    text = str(text)
    found_addresses = re.findall(address_pattern, text)
    return found_addresses


def extract_addresses_from_csv(file_path):
    """
    CSV 파일에서 A열과 B열을 읽고, B열의 텍스트 내에서 한국 주소를 찾아 A열의 판례일련번호와 연결합니다.

    :param file_path: CSV 파일의 경로
    :return: 판례일련번호와 찾은 주소 목록
    """
    df = pd.read_csv(file_path)
    df['Found_Addresses'] = df['판례내용'].apply(find_korean_addresses)

    return df[df['Found_Addresses'].map(lambda d: len(d) > 0)][['판례일련번호', 'Found_Addresses']]

# CSV 파일 경로
csv_file_path = '/content/비실명화_형사.csv'  # 여기에 실제 파일 경로를 입력하세요.

# CSV 파일에서 주소 추출 및 판례일련번호와 연결
address_data = extract_addresses_from_csv(csv_file_path)

# 결과 출력
for index, row in address_data.iterrows():
    print(f"판례일련번호: {row['판례일련번호']}, 찾은 주소: {row['Found_Addresses']}")
# Out:
# 판례일련번호: 70048.0, 찾은 주소: ['덕진구 인후동 1', '덕진구 인후동 1']
# 판례일련번호: 70073.0, 찾은 주소: ['강남구 논현동 70-6', '동대문구 장안동 414-6']
# 판례일련번호: 70074.0, 찾은 주소: ['북구 백운동 650']
# 판례일련번호: 70096.0, 찾은 주소: ['강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 112', '강동구 명일동 327-24', '강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 327-24']
# 판례일련번호: 70097.0, 찾은 주소: ['동구 수정동 625-33']
# 판례일련번호: 70102.0, 찾은 주소: ['북구 문흥동 160']
# 판례일련번호: 70104.0, 찾은 주소: ['강남구 압구정동 486']
# 판례일련번호: 70155.0, 찾은 주소: ['송파구 가락동 600']
# 판례일련번호: 70157.0, 찾은 주소: ['중구 황학동 688']
# 판례일련번호: 70188.0, 찾은 주소: ['북구 중흥동 260-3']
# 판례일련번호: 70213.0, 찾은 주소: ['용산구 갈월동 98']
# 판례일련번호: 70377.0, 찾은 주소: ['수성구 범물동 1336']
# 판례일련번호: 70590.0, 찾은 주소: ['수성구 범어동 45-37']
# 판례일련번호: 70674.0, 찾은 주소: ['남동구 고잔동 512-12']
# 판례일련번호: 70675.0, 찾은 주소: ['마포구 용강동 38']
# 판례일련번호: 70759.0, 찾은 주소: ['용산구 동부이촌동 160']
# 판례일련번호: 70783.0, 찾은 주소: ['서대문구 북가좌동 292-17']
# 판례일련번호: 70816.0, 찾은 주소: ['마포구 용강동 51-8']
# 판례일련번호: 70822.0, 찾은 주소: ['남동구 고잔동 641-6']
# 판례일련번호: 70824.0, 찾은 주소: ['강남구 삼성동 141']
# 판례일련번호: 70848.0, 찾은 주소: ['은평구 수색동 17-9']
# 판례일련번호: 70850.0, 찾은 주소: ['남동구 구월동 1280']
# 판례일련번호: 70885.0, 찾은 주소: ['흥덕구 분평동 1224']
# 판례일련번호: 70906.0, 찾은 주소: ['중랑구 신내동 646']
# 판례일련번호: 70909.0, 찾은 주소: ['서대문구 홍제동 462']
# 판례일련번호: 70981.0, 찾은 주소: ['서구 비산네거리 425', '서구 비산네거리 425']
# 판례일련번호: 71043.0, 찾은 주소: ['연제구 연산동 584-1']
# 판례일련번호: 71044.0, 찾은 주소: ['중구 대사동 640']
# 판례일련번호: 71071.0, 찾은 주소: ['영등포구 문래동3']
# 판례일련번호: 71171.0, 찾은 주소: ['성북구 종암동 3']
# 판례일련번호: 71536.0, 찾은 주소: ['장안구 화서동 650']
# 판례일련번호: 71565.0, 찾은 주소: ['중원구 상대원동 279-1']
# 판례일련번호: 71567.0, 찾은 주소: ['서대문구 북아현동 176-116', '서대문구 북아현동 176-116']
# 판례일련번호: 71591.0, 찾은 주소: ['중구 용두동 188']
# 판례일련번호: 76187.0, 찾은 주소: ['중구 달성동 294']
# 판례일련번호: 76262.0, 찾은 주소: ['구로구 시흥동 985-1', '구로구 시흥동 985-1']
# 판례일련번호: 76269.0, 찾은 주소: ['강남구 가락동 321', '종로구 옥인동 13', '강동구 가락동 321', '강남구 가락동 321', '성동구 구의동 230']
# 판례일련번호: 76273.0, 찾은 주소: ['남구 민락동 168']
# 판례일련번호: 76275.0, 찾은 주소: ['남구 대명동 82']
# 판례일련번호: 76278.0, 찾은 주소: ['은평구 구산동 8', '중구 회현동 1', '종로구 중학동 4']
# 판례일련번호: 76439.0, 찾은 주소: ['강남구 방배동 915']
# 판례일련번호: 76441.0, 찾은 주소: ['서구 내동1']
# 판례일련번호: 76546.0, 찾은 주소: ['영등포구 양평동 1']
# 판례일련번호: 76548.0, 찾은 주소: ['관악구 신림동 112']
# 판례일련번호: 76549.0, 찾은 주소: ['강남구 논현동 199', '강남구 논현동 199']
# 판례일련번호: 76626.0, 찾은 주소: ['마포구 노고산동 107']
# 판례일련번호: 76688.0, 찾은 주소: ['강남구 역삼동 736']
# 판례일련번호: 76689.0, 찾은 주소: ['중구 대청동 2', '중구 대청동 1']
# 판례일련번호: 76694.0, 찾은 주소: ['성동구 풍납동 281']
# 판례일련번호: 76700.0, 찾은 주소: ['해주군 용당리 242']
# 판례일련번호: 76715.0, 찾은 주소: ['강남구 삼성동 159']
# 판례일련번호: 76978.0, 찾은 주소: ['강남구 서초동 1303']
# 판례일련번호: 76985.0, 찾은 주소: ['중구 만리동 126']
# 판례일련번호: 77093.0, 찾은 주소: ['중구 해안동 2']
# 판례일련번호: 77096.0, 찾은 주소: ['북구 효성동 401']
# 판례일련번호: 77101.0, 찾은 주소: ['북구 칠성동 2', '중구 삼덕동 2']
# 판례일련번호: 79089.0, 찾은 주소: ['동작구 사당동 2-2']
# 판례일련번호: 79090.0, 찾은 주소: ['중구 영주동 743']
# 판례일련번호: 79178.0, 찾은 주소: ['북구 노원동 3']
# 판례일련번호: 79182.0, 찾은 주소: ['달서구 본동 1']
# 판례일련번호: 80713.0, 찾은 주소: ['강남구 역삼동 831']
# 판례일련번호: 80833.0, 찾은 주소: ['서구 부민동 1', '서구 부민동 2']
# 판례일련번호: 80869.0, 찾은 주소: ['일산구 주엽동 17']
# 판례일련번호: 80970.0, 찾은 주소: ['영등포구 신길동 60']
# 판례일련번호: 81012.0, 찾은 주소: ['중구 서소문동 14']
# 판례일련번호: 81776.0, 찾은 주소: ['일산구 탄현동 1249']
# 판례일련번호: 81894.0, 찾은 주소: ['중구 항동7']
# 판례일련번호: 81963.0, 찾은 주소: ['동대문구 답십리 4']
# 판례일련번호: 82176.0, 찾은 주소: ['서초구 방배동 824']
# 판례일련번호: 82739.0, 찾은 주소: ['서초구 서초동 1701-1']
# 판례일련번호: 82771.0, 찾은 주소: ['오정구 여월동 6-1']
# 판례일련번호: 82931.0, 찾은 주소: ['북구 동빈동 1']
# 판례일련번호: 83290.0, 찾은 주소: ['광진구 자양동 597-9']
# 판례일련번호: 83570.0, 찾은 주소: ['동구 범일동 830']
# 판례일련번호: 83918.0, 찾은 주소: ['계양구 계산동 1083-7']
# 판례일련번호: 83921.0, 찾은 주소: ['성북구 동선동 1']
# 판례일련번호: 83940.0, 찾은 주소: ['분당구 서현동 91']
# 판례일련번호: 85037.0, 찾은 주소: ['계양구 효성동 515-9', '계양구 효성동 515-9']
