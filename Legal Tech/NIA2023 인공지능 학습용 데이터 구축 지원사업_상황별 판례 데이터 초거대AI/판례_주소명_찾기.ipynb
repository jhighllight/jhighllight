# %% [markdown]
# **판례 주소명 찾기**
#
# * 데이터: 형사법 12,154건
# * 데이터 형식: csv 파일
# * 코드 원리: 정규표현식
# * 코드 결과: 한국의 주소를 찾기에 적합한 성능으로 일상에서 사용하기에 용이

# %%
#시부터 시작하고, 순서대로 출력

import pandas as pd
import re

def find_korean_addresses(text):
    """
    주어진 텍스트에서 한국 주소 형식에 맞는 문자열을 찾습니다.

    :param text: 검색할 전체 텍스트
    :return: 찾은 주소 목록
    """
    # 시부터 시작하고, 마지막에 '가' 또는 '의 숫자'를 포함하는 주소 패턴
    address_pattern = r'([가-힣]+(?:시|도)\s?[가-힣]+(?:구|군)?\s?[가-힣]+(?:동|면|리)\s?\d+(?:-\d+)?(?:의\s?\d+)?(?:가|나|다|라|마|바|사|아|자|차|카|타|파|하)?)'
    text = str(text)
    found_addresses = re.findall(address_pattern, text)
    return found_addresses


def extract_addresses_from_csv(file_path):
    """
    CSV 파일에서 A열과 B열을 읽고, B열의 텍스트 내에서 한국 주소를 찾아 A열의 판례일련번호와 연결합니다.

    :param file_path: CSV 파일의 경로
    :return: 판례일련번호와 찾은 주소 목록
    """
    df = pd.read_csv(file_path)
    df['Found_Addresses'] = df['판례내용'].apply(find_korean_addresses)

    return df[df['Found_Addresses'].map(lambda d: len(d) > 0)][['판례일련번호', 'Found_Addresses']]

# CSV 파일 경로
csv_file_path = '/content/비실명화_형사.csv'  # 여기에 실제 파일 경로를 입력하세요.

# CSV 파일에서 주소 추출 및 판례일련번호와 연결
address_data = extract_addresses_from_csv(csv_file_path)

# 결과 출력
for index, row in address_data.iterrows():
    print(f"판례일련번호: {row['판례일련번호']}, 찾은 주소: {row['Found_Addresses']}")
# Out:
# 판례일련번호: 64477, 찾은 주소: ['의정부시 신곡동 679']
# 판례일련번호: 64832, 찾은 주소: ['남양주시 수동면 수산리 167', '남양주시 수동면 수산리 167']
# 판례일련번호: 65129, 찾은 주소: ['양주시 율정동 281', '양주시 율정동 2의 16']
# 판례일련번호: 67163, 찾은 주소: ['진주시 일반성면 창촌리 53-3', '진주시 일반성면 남산리 1225', '진주시 일반성면 창촌리 666-5', '진주시 일반성면 창촌리 22', '진주시 일반성면 창촌리 698-1']
# 판례일련번호: 67223, 찾은 주소: ['진주시 칠암동 90']
# 판례일련번호: 67482, 찾은 주소: ['수원시 권선구 고색동 886', '수원시 권선구 고색동 886-11']
# 판례일련번호: 67497, 찾은 주소: ['수원시 권선구 평동 151']
# 판례일련번호: 67641, 찾은 주소: ['알코올농도를 계산하면 0']
# 판례일련번호: 67723, 찾은 주소: ['하남시 덕풍동 378-7']
# 판례일련번호: 67753, 찾은 주소: ['원주시 평원동 349-1']
# 판례일련번호: 67758, 찾은 주소: ['남원시 주천면 용담리 344', '남원시 주천면 용담리 172', '남원시 광치동 548-3']
# 판례일련번호: 68242, 찾은 주소: ['혈중알코올농도를 계산하면 0']
# 판례일련번호: 68289, 찾은 주소: ['시흥시사무전결처리규칙개정규칙에 의하면 7']
# 판례일련번호: 68795, 찾은 주소: ['수입시와 달리 2차']
# 판례일련번호: 69087, 찾은 주소: ['성남시 분당구 정자동 6']
# 판례일련번호: 69529, 찾은 주소: ['경주시 강동면 유금리 1020의 2']
# 판례일련번호: 69565, 찾은 주소: ['천안시 쌍용동 567']
# 판례일련번호: 69634, 찾은 주소: ['전주시 덕진구 인후동2가']
# 판례일련번호: 69754, 찾은 주소: ['광주시 퇴촌면 관음리 549-10']
# 판례일련번호: 69787, 찾은 주소: ['마산시 회성동 233-7']
# 판례일련번호: 69862, 찾은 주소: ['전주시 덕진구 우아동 3가']
# 판례일련번호: 69883, 찾은 주소: ['있도록 투자하면 1']
# 판례일련번호: 69908, 찾은 주소: ['원주시 신림면 성남리 943-4', '원주시 신림면 성남리 943']
# 판례일련번호: 69933, 찾은 주소: ['과천시 중앙동 2']
# 판례일련번호: 69952, 찾은 주소: ['전주시 덕진구 송천동2가', '전주시 덕진구 송천동2가']
# 판례일련번호: 69973, 찾은 주소: ['제천시 의림동 3-3']
# 판례일련번호: 69974, 찾은 주소: ['광주시 오포읍 매산리 584-4']
# 판례일련번호: 69999, 찾은 주소: ['화성시 향남면 장짐리 273의 1']
# 판례일련번호: 70027, 찾은 주소: ['의정부시 금오동 475-1', '의정부시 금오동 475-1', '의정부시 금오동 475-1']
# 판례일련번호: 70048, 찾은 주소: ['전주시 덕진구 인후동 1가', '전주시 덕진구 인후동 1가']
# 판례일련번호: 70075, 찾은 주소: ['양산시 북정동 552의 2']
# 판례일련번호: 70188, 찾은 주소: ['광양시 황금동 200']
# 판례일련번호: 70812, 찾은 주소: ['원주시 명륜동 459', '원주시 명륜동 459']
# 판례일련번호: 70813, 찾은 주소: ['강릉시 성남동 110-5']
# 판례일련번호: 70885, 찾은 주소: ['청주시 흥덕구 분평동 1224', '청주시 분평동 1224', '청주시 분평동 1224']
# 판례일련번호: 70907, 찾은 주소: ['영천시 고경면 해선리 317-9']
# 판례일련번호: 71247, 찾은 주소: ['보령시 동대동 1865']
# 판례일련번호: 71248, 찾은 주소: ['안산시 고잔동 437의 4', '안산시 고잔동 537의 4']
# 판례일련번호: 71249, 찾은 주소: ['강릉시 사천면 415', '강릉시 사천면 415']
# 판례일련번호: 71536, 찾은 주소: ['수원시 장안구 화서동 650']
# 판례일련번호: 71564, 찾은 주소: ['상주시 낙동면 구잠리 222']
# 판례일련번호: 71565, 찾은 주소: ['성남시 중원구 상대원동 279-1']
# 판례일련번호: 76090, 찾은 주소: ['송탄시 서정동 239']
# 판례일련번호: 76095, 찾은 주소: ['전주시 인후동 1가']
# 판례일련번호: 76262, 찾은 주소: ['안양시 박달동 68']
# 판례일련번호: 76269, 찾은 주소: ['부천시 삼정동 272']
# 판례일련번호: 76441, 찾은 주소: ['대구시 서구 내동1']
# 판례일련번호: 76454, 찾은 주소: ['구미시 공단동 2', '구미시 공당동 2', '구미시 공단동 2']
# 판례일련번호: 76536, 찾은 주소: ['송탄시 장당동 390의 1', '다시 같은시 이충동 459']
# 판례일련번호: 76541, 찾은 주소: ['부천시 소사동 93의 19', '부천시 소사동 93의 19']
# 판례일련번호: 76548, 찾은 주소: ['서울시 관악구 신림동 112의 39', '수원시 신풍동 305의 2']
# 판례일련번호: 76549, 찾은 주소: ['강릉시 명주동 4의 1', '강릉시 명주동 4의 1']
# 판례일련번호: 76700, 찾은 주소: ['황해도 해주군 용당리 242']
# 판례일련번호: 76712, 찾은 주소: ['부천시 소사동 294의 64']
# 판례일련번호: 77089, 찾은 주소: ['마산시 상남동 136']
# 판례일련번호: 80617, 찾은 주소: ['남양주시 진접읍 장현리 17']
# 판례일련번호: 80753, 찾은 주소: ['남양주시 수동면 수산리 217의 3']
# 판례일련번호: 80869, 찾은 주소: ['고양시 일산구 주엽동 17']
# 판례일련번호: 81776, 찾은 주소: ['고양시 일산구 탄현동 1249']
# 판례일련번호: 82771, 찾은 주소: ['부천시 오정구 여월동 6-1']
# 판례일련번호: 82931, 찾은 주소: ['포항시 북구 동빈동 1가']
# 판례일련번호: 83940, 찾은 주소: ['성남시 분당구 서현동 91']
# 판례일련번호: 85829, 찾은 주소: ['혈중알코올농도를 계산해보면 0']
# 판례일련번호: 101056, 찾은 주소: ['서울시 관악구 신림동 112의 39']
# 판례일련번호: 101500, 찾은 주소: ['다시 만나 같은동 379의 11']
# 판례일련번호: 102368, 찾은 주소: ['인천시 중구 경동161-1']
# 판례일련번호: 103082, 찾은 주소: ['중도금조로 액면 431']
# 판례일련번호: 103795, 찾은 주소: ['대구직할시 노원동 3가']
# 판례일련번호: 103956, 찾은 주소: ['진주시 상평동 278']
# 판례일련번호: 107351, 찾은 주소: ['받았음에도 불구하고 소꼬리 20']
# 판례일련번호: 108548, 찾은 주소: ['거시증거에 의하면1989']
# 판례일련번호: 111806, 찾은 주소: ['마산시 합포구 창포동 3가']
# 판례일련번호: 116655, 찾은 주소: ['원주시 반곡동 1602의 1']
# 판례일련번호: 116898, 찾은 주소: ['창원시 사파동 1']
# 판례일련번호: 117690, 찾은 주소: ['동두천시 생연동 400의 3']
# 판례일련번호: 118486, 찾은 주소: ['대전시 동구 원동 21의6']
# 판례일련번호: 119225, 찾은 주소: ['광명시 하안동 10']
# 판례일련번호: 120572, 찾은 주소: ['부천시 원미구 상동 464의 4']
# 판례일련번호: 120796, 찾은 주소: ['수원시 팔달구 매탄동 198의 51']
# 판례일련번호: 120797, 찾은 주소: ['공익시설 봉사활동 120', '창원시 사파동 52의 3']
# 판례일련번호: 121065, 찾은 주소: ['나주시 중앙동 4의 6', '나주시 중앙동 4의 6']
# 판례일련번호: 133490, 찾은 주소: ['수원시 팔달구 화성동 115-5']
# 판례일련번호: 139128, 찾은 주소: ['천안시 신부동 72-16']
# 판례일련번호: 139129, 찾은 주소: ['신라시대 목짧은항아리 2']
# 판례일련번호: 140326, 찾은 주소: ['혈중알콜농도를 계산해보면 0']
# 판례일련번호: 141561, 찾은 주소: ['고양시 덕양구 화정동 996-2']
# 판례일련번호: 141564, 찾은 주소: ['청주시 상당구 용담동 173-9']
# 판례일련번호: 142029, 찾은 주소: ['김해시 삼계동 117', '김해시 서상동 27-24', '김해시 동상동 727-1', '김해시 삼계동 117', '김해시 삼계동 117']
# 판례일련번호: 142098, 찾은 주소: ['고양시 덕양구 원당동 672-1']
# 판례일련번호: 142485, 찾은 주소: ['광양시 광양읍 칠성리 603-1']
# 판례일련번호: 143201, 찾은 주소: ['논산시 벌곡면 신양리 18-2']
# 판례일련번호: 143652, 찾은 주소: ['경주시 용강동 1228-3', '경주시 황성동 1053-71']
# 판례일련번호: 148929, 찾은 주소: ['광양시 광양읍 인서리 475-16']
# 판례일련번호: 149913, 찾은 주소: ['성남시 분당구 구미동 175']
# 판례일련번호: 157314, 찾은 주소: ['성남시 분당구 운중동 960', '성남시 분당구 판교동 526-3']
# 판례일련번호: 158777, 찾은 주소: ['김해시 삼정동 591-2']
# 판례일련번호: 159944, 찾은 주소: ['전주시 완산구 삼천동 1가']
# 판례일련번호: 160428, 찾은 주소: ['안양시 동안구 호계동 1054-6']
# 판례일련번호: 160713, 찾은 주소: ['고양시 일산서구 탄현동 439']
# 판례일련번호: 161834, 찾은 주소: ['고양시 덕양구 화정동 952']
# 판례일련번호: 163547, 찾은 주소: ['의정부시 민락동 576']
# 판례일련번호: 163583, 찾은 주소: ['부천시 원미구 중동 1173']
# 판례일련번호: 169491, 찾은 주소: ['용인시 처인구 고림동 191-6']
# 판례일련번호: 179115, 찾은 주소: ['한도액을 연리 2']
# 판례일련번호: 179265, 찾은 주소: ['염산리도카인젤리2', '염산리도카인젤리2']
# 판례일련번호: 183437, 찾은 주소: ['다시 참여하게 되면 20']
# 판례일련번호: 190007, 찾은 주소: ['정도와 달리 4']
# 판례일련번호: 190053, 찾은 주소: ['나주시 성북동 15']
# 판례일련번호: 190216, 찾은 주소: ['천안시 목천면 운전리 25의 1', '과천시 별양동 1의 23']
# 판례일련번호: 190272, 찾은 주소: ['대전시 유성구 가정동 35']
# 판례일련번호: 190294, 찾은 주소: ['김포시 고촌면 태리 916']
# 판례일련번호: 191936, 찾은 주소: ['부천시 원미구 중동 883']
# 판례일련번호: 192862, 찾은 주소: ['보령시 웅천읍 대창리 872-1']
# 판례일련번호: 192865, 찾은 주소: ['논산시 부적면 외성리 317-23']
# 판례일련번호: 221717, 찾은 주소: ['해체시킨 동바리 2']
# 판례일련번호: 222969, 찾은 주소: ['과천시 별양동 5']
# 판례일련번호: 222997, 찾은 주소: ['사망시각을 추정하면 6']
# 판례일련번호: 223181, 찾은 주소: ['충주시 문화동 739의 8', '충주시 문화동 739의 8']
# 판례일련번호: 227285, 찾은 주소: ['부산시 중구 중앙동 50의 7', '부산시 동구 범일동 830의 18']
# 판례일련번호: 227649, 찾은 주소: ['안양시 안양동 817의 21']
# 판례일련번호: 227659, 찾은 주소: ['안산시 본오동 312', '안산시 본오동 312', '안산시 본오동 312']
# 판례일련번호: 228579, 찾은 주소: ['부천시 괴안동 87의 14', '시흥시 대야동 408', '시흥시 대야동 408']
# 판례일련번호: 228637, 찾은 주소: ['청주시 문화동 109의2']
# 판례일련번호: 229269, 찾은 주소: ['안산시 팔곡동 410']
# 판례일련번호: 229479, 찾은 주소: ['평택시 칠괴동 150의 3']
# 판례일련번호: 231127, 찾은 주소: ['안동시 동부동 200', '안동시 당북동 109']
# 판례일련번호: 231239, 찾은 주소: ['울산시 일산동 155']

# %%
#군이나 구부터 시작하고, 순서대로 출력

import pandas as pd
import re

def find_korean_addresses(text):
    """
    주어진 텍스트에서 한국 주소 형식에 맞는 문자열을 찾습니다.

    :param text: 검색할 전체 텍스트
    :return: 찾은 주소 목록
    """
    # 군이나 구부터 시작하고, 마지막에 '가' 또는 '의 숫자'를 포함하는 주소 패턴
    address_pattern = r'([가-힣]+(?:구|군)\s?[가-힣]+(?:동|면|리)\s?\d+(?:-\d+)?(?:의\s?\d+)?(?:가|나|다|라|마|바|사|아|자|차|카|타|파|하)?)'
    text = str(text)
    found_addresses = re.findall(address_pattern, text)
    return found_addresses


def extract_addresses_from_csv(file_path):
    """
    CSV 파일에서 A열과 B열을 읽고, B열의 텍스트 내에서 한국 주소를 찾아 A열의 판례일련번호와 연결합니다.

    :param file_path: CSV 파일의 경로
    :return: 판례일련번호와 찾은 주소 목록
    """
    df = pd.read_csv(file_path)
    df['Found_Addresses'] = df['판례내용'].apply(find_korean_addresses)

    return df[df['Found_Addresses'].map(lambda d: len(d) > 0)][['판례일련번호', 'Found_Addresses']]

# CSV 파일 경로
csv_file_path = '/content/비실명화_형사.csv'  # 여기에 실제 파일 경로를 입력하세요.

# CSV 파일에서 주소 추출 및 판례일련번호와 연결
address_data = extract_addresses_from_csv(csv_file_path)

# 결과 출력
for index, row in address_data.iterrows():
    print(f"판례일련번호: {row['판례일련번호']}, 찾은 주소: {row['Found_Addresses']}")
# Out:
# 판례일련번호: 65128, 찾은 주소: ['대덕구 석봉동 177의 7']
# 판례일련번호: 67362, 찾은 주소: ['부평구 부평동 549의 38']
# 판례일련번호: 67482, 찾은 주소: ['권선구 고색동 886', '권선구 고색동 886-11']
# 판례일련번호: 67497, 찾은 주소: ['권선구 평동 151']
# 판례일련번호: 67501, 찾은 주소: ['영등포구 여의도동 63']
# 판례일련번호: 67752, 찾은 주소: ['금천구 기산동 140-25']
# 판례일련번호: 67796, 찾은 주소: ['강남구 논현동 63-9']
# 판례일련번호: 68103, 찾은 주소: ['영등포구 여의도동 23-2']
# 판례일련번호: 69011, 찾은 주소: ['동구 화평동 66', '남구 주안동 197의 20']
# 판례일련번호: 69087, 찾은 주소: ['분당구 정자동 6']
# 판례일련번호: 69181, 찾은 주소: ['서구 화정동 1051', '서구 화정동 1051']
# 판례일련번호: 69284, 찾은 주소: ['남구 대연동 243-23']
# 판례일련번호: 69427, 찾은 주소: ['광진구 화양동 111의 102']
# 판례일련번호: 69528, 찾은 주소: ['중구 선화동 21-13', '중구 선화동 21-13', '중구 선화동 21-13', '중구 선화동 21-13', '중구 선화동 21-13']
# 판례일련번호: 69530, 찾은 주소: ['종로구 봉익동 23', '종로구 봉익동 23']
# 판례일련번호: 69562, 찾은 주소: ['강동구 천호동 454-2', '강동구 천호동 454-2', '영등포구 영등포동 434-5']
# 판례일련번호: 69563, 찾은 주소: ['강남구 역삼동 676', '강남구 역삼동 676']
# 판례일련번호: 69564, 찾은 주소: ['성동구 송정동 79-2', '서초구 서초동 1624-4']
# 판례일련번호: 69591, 찾은 주소: ['종로구 관철동 10-2']
# 판례일련번호: 69617, 찾은 주소: ['관악구 봉천동 874-9']
# 판례일련번호: 69634, 찾은 주소: ['덕진구 인후동2가']
# 판례일련번호: 69699, 찾은 주소: ['영등포구 당산동 3가']
# 판례일련번호: 69704, 찾은 주소: ['마포구 중동 25-3']
# 판례일련번호: 69756, 찾은 주소: ['구로구 궁동 213-21']
# 판례일련번호: 69808, 찾은 주소: ['강남구 삼성동 142-43']
# 판례일련번호: 69810, 찾은 주소: ['수성구 범어동 33-2', '중구 명동 2가', '서구 평리동 655-15']
# 판례일련번호: 69811, 찾은 주소: ['남동구 논현동 446의 5']
# 판례일련번호: 69812, 찾은 주소: ['북구 운암동 154-60', '동구 대의동 58']
# 판례일련번호: 69833, 찾은 주소: ['송파구 신천동 7-19']
# 판례일련번호: 69859, 찾은 주소: ['동구 수기동 23-2']
# 판례일련번호: 69860, 찾은 주소: ['송파구 석촌동 273-5', '송파구 석촌동 273의 5']
# 판례일련번호: 69862, 찾은 주소: ['덕진구 우아동 3가']
# 판례일련번호: 69881, 찾은 주소: ['남구 월산동 344']
# 판례일련번호: 69883, 찾은 주소: ['강남구 역삼동 702-10']
# 판례일련번호: 69906, 찾은 주소: ['성북구 동선동 1가', '성북구 동선동 92-7', '성북구 동선동 1가', '성북구 동선동 1가']
# 판례일련번호: 69928, 찾은 주소: ['용산구 한남동 737-28']
# 판례일련번호: 69933, 찾은 주소: ['서초구 서초동 1675-1']
# 판례일련번호: 69934, 찾은 주소: ['성동구 마장동 507-5']
# 판례일련번호: 69935, 찾은 주소: ['동대문구 황학동 274', '중구 북성동 1가', '마포구 마포동 230-16', '영등포구 영등포동 3가', '동대문구 이문동 258-39', '서대문구 창천동 13-52']
# 판례일련번호: 69949, 찾은 주소: ['광산구 소촌동 1-4', '광산구 소촌동 1-4']
# 판례일련번호: 69950, 찾은 주소: ['수영구 민락동 179-7']
# 판례일련번호: 69952, 찾은 주소: ['덕진구 송천동2가', '덕진구 송천동2가']
# 판례일련번호: 69974, 찾은 주소: ['강남구 역삼동 678-39', '강남구 논현동 126-5', '강남구 삼성동 157-8', '송파구 오금동 162', '강남구 청담동 132-19', '송파구 오금동 162', '강남구 청담동 132-19', '서대문구 대현동 101-7']
# 판례일련번호: 70001, 찾은 주소: ['수성구 지산동 761-10']
# 판례일련번호: 70002, 찾은 주소: ['남구 주안동 982의 1', '남동구 만수동 109의 382', '남구 주안동 106의 6']
# 판례일련번호: 70026, 찾은 주소: ['서구 서대신동3가']
# 판례일련번호: 70048, 찾은 주소: ['덕진구 인후동 1가', '덕진구 인후동 1가']
# 판례일련번호: 70073, 찾은 주소: ['강남구 논현동 70-6', '동대문구 장안동 414-6']
# 판례일련번호: 70074, 찾은 주소: ['북구 백운동 650의 8']
# 판례일련번호: 70096, 찾은 주소: ['강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 112', '강동구 명일동 327-24', '강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 112', '강동구 명일동 327-6', '강동구 명일동 327-24']
# 판례일련번호: 70097, 찾은 주소: ['동구 수정동 625-33']
# 판례일련번호: 70102, 찾은 주소: ['북구 문흥동 160']
# 판례일련번호: 70104, 찾은 주소: ['강남구 압구정동 486']
# 판례일련번호: 70155, 찾은 주소: ['송파구 가락동 600']
# 판례일련번호: 70157, 찾은 주소: ['중구 황학동 688']
# 판례일련번호: 70188, 찾은 주소: ['북구 중흥동 260-3']
# 판례일련번호: 70213, 찾은 주소: ['용산구 갈월동 98']
# 판례일련번호: 70377, 찾은 주소: ['수성구 범물동 1336']
# 판례일련번호: 70590, 찾은 주소: ['수성구 범어동 45-37']
# 판례일련번호: 70674, 찾은 주소: ['남동구 고잔동 512-12']
# 판례일련번호: 70675, 찾은 주소: ['마포구 용강동 38의 1']
# 판례일련번호: 70759, 찾은 주소: ['용산구 동부이촌동 160']
# 판례일련번호: 70783, 찾은 주소: ['서대문구 북가좌동 292-17']
# 판례일련번호: 70816, 찾은 주소: ['마포구 용강동 51-8']
# 판례일련번호: 70822, 찾은 주소: ['남동구 고잔동 641-6']
# 판례일련번호: 70824, 찾은 주소: ['강남구 삼성동 141']
# 판례일련번호: 70848, 찾은 주소: ['은평구 수색동 17-9']
# 판례일련번호: 70850, 찾은 주소: ['남동구 구월동 1280의 3']
# 판례일련번호: 70885, 찾은 주소: ['흥덕구 분평동 1224']
# 판례일련번호: 70906, 찾은 주소: ['중랑구 신내동 646']
# 판례일련번호: 70909, 찾은 주소: ['서대문구 홍제동 462']
# 판례일련번호: 70981, 찾은 주소: ['서구 비산네거리 425', '서구 비산네거리 425']
# 판례일련번호: 71043, 찾은 주소: ['연제구 연산동 584-1']
# 판례일련번호: 71044, 찾은 주소: ['중구 대사동 640']
# 판례일련번호: 71071, 찾은 주소: ['영등포구 문래동3가']
# 판례일련번호: 71171, 찾은 주소: ['성북구 종암동 3의 142']
# 판례일련번호: 71536, 찾은 주소: ['장안구 화서동 650']
# 판례일련번호: 71565, 찾은 주소: ['중원구 상대원동 279-1']
# 판례일련번호: 71567, 찾은 주소: ['서대문구 북아현동 176-116', '서대문구 북아현동 176-116']
# 판례일련번호: 71591, 찾은 주소: ['중구 용두동 188']
# 판례일련번호: 76187, 찾은 주소: ['중구 달성동 294']
# 판례일련번호: 76262, 찾은 주소: ['구로구 시흥동 985-1', '구로구 시흥동 985-1']
# 판례일련번호: 76269, 찾은 주소: ['강남구 가락동 321', '종로구 옥인동 13의 1가', '강동구 가락동 321', '강남구 가락동 321', '성동구 구의동 230의 1']
# 판례일련번호: 76273, 찾은 주소: ['남구 민락동 168의 13']
# 판례일련번호: 76275, 찾은 주소: ['남구 대명동 82의 5']
# 판례일련번호: 76278, 찾은 주소: ['은평구 구산동 8의 3', '중구 회현동 1가', '종로구 중학동 4']
# 판례일련번호: 76439, 찾은 주소: ['강남구 방배동 915의 2']
# 판례일련번호: 76441, 찾은 주소: ['서구 내동1']
# 판례일련번호: 76546, 찾은 주소: ['영등포구 양평동 1가']
# 판례일련번호: 76548, 찾은 주소: ['관악구 신림동 112의 39']
# 판례일련번호: 76549, 찾은 주소: ['강남구 논현동 199', '강남구 논현동 199']
# 판례일련번호: 76626, 찾은 주소: ['마포구 노고산동 107']
# 판례일련번호: 76688, 찾은 주소: ['강남구 역삼동 736의 16']
# 판례일련번호: 76689, 찾은 주소: ['중구 대청동 2가', '중구 대청동 1가']
# 판례일련번호: 76694, 찾은 주소: ['성동구 풍납동 281']
# 판례일련번호: 76700, 찾은 주소: ['해주군 용당리 242']
# 판례일련번호: 76715, 찾은 주소: ['강남구 삼성동 159']
# 판례일련번호: 76978, 찾은 주소: ['강남구 서초동 1303의 35']
# 판례일련번호: 76985, 찾은 주소: ['중구 만리동 126']
# 판례일련번호: 77093, 찾은 주소: ['중구 해안동 2가']
# 판례일련번호: 77096, 찾은 주소: ['북구 효성동 401의 1']
# 판례일련번호: 77101, 찾은 주소: ['북구 칠성동 2가', '중구 삼덕동 2가']
# 판례일련번호: 79089, 찾은 주소: ['동작구 사당동 2-2']
# 판례일련번호: 79090, 찾은 주소: ['중구 영주동 743의 80']
# 판례일련번호: 79178, 찾은 주소: ['북구 노원동 3가']
# 판례일련번호: 79182, 찾은 주소: ['달서구 본동 1']
# 판례일련번호: 80713, 찾은 주소: ['강남구 역삼동 831']
# 판례일련번호: 80833, 찾은 주소: ['서구 부민동 1가', '서구 부민동 2가']
# 판례일련번호: 80869, 찾은 주소: ['일산구 주엽동 17']
# 판례일련번호: 80970, 찾은 주소: ['영등포구 신길동 60의 4']
# 판례일련번호: 81012, 찾은 주소: ['중구 서소문동 14의 2']
# 판례일련번호: 81776, 찾은 주소: ['일산구 탄현동 1249']
# 판례일련번호: 81894, 찾은 주소: ['중구 항동7가']
# 판례일련번호: 81963, 찾은 주소: ['동대문구 답십리 4']
# 판례일련번호: 82176, 찾은 주소: ['서초구 방배동 824']
# 판례일련번호: 82739, 찾은 주소: ['서초구 서초동 1701-1']
# 판례일련번호: 82771, 찾은 주소: ['오정구 여월동 6-1']
# 판례일련번호: 82931, 찾은 주소: ['북구 동빈동 1가']
# 판례일련번호: 83290, 찾은 주소: ['광진구 자양동 597-9']
# 판례일련번호: 83570, 찾은 주소: ['동구 범일동 830의 134']
# 판례일련번호: 83918, 찾은 주소: ['계양구 계산동 1083-7']
# 판례일련번호: 83921, 찾은 주소: ['성북구 동선동 1가']
# 판례일련번호: 83940, 찾은 주소: ['분당구 서현동 91']
# 판례일련번호: 85037, 찾은 주소: ['계양구 효성동 515-9', '계양구 효성동 515-9']
# 판례일련번호: 100413, 찾은 주소: ['같은구 휘경동 34']
# 판례일련번호: 100461, 찾은 주소: ['동대문구 중화동 331의 67']
# 판례일련번호: 100583, 찾은 주소: ['서구 평리 1']
# 판례일련번호: 101056, 찾은 주소: ['관악구 신림동 112의 39']
# 판례일련번호: 101363, 찾은 주소: ['남구 용현동 42']
# 판례일련번호: 101439, 찾은 주소: ['성동구 구의동 234']
# 판례일련번호: 102059, 찾은 주소: ['마포구 염리동 151']
# 판례일련번호: 102173, 찾은 주소: ['동대문구 제기동 857']
# 판례일련번호: 102368, 찾은 주소: ['중구 경동161-1']
# 판례일련번호: 102585, 찾은 주소: ['중구 대신동 1942']
# 판례일련번호: 102736, 찾은 주소: ['중구 대청동 1가']
# 판례일련번호: 107016, 찾은 주소: ['도봉구 창동 749']
# 판례일련번호: 111806, 찾은 주소: ['합포구 창포동 3가']
# 판례일련번호: 112970, 찾은 주소: ['중구 부평동 2가']
# 판례일련번호: 112974, 찾은 주소: ['서구 평리 2']
# 판례일련번호: 115951, 찾은 주소: ['중구 신포동 2']
# 판례일련번호: 117695, 찾은 주소: ['송파구 신천동 7의 13']
# 판례일련번호: 117795, 찾은 주소: ['성동구 용답동 233의 10']
# 판례일련번호: 118486, 찾은 주소: ['동구 원동 21의6']
# 판례일련번호: 118565, 찾은 주소: ['서대문구 신촌동 134']
# 판례일련번호: 118566, 찾은 주소: ['마포구 대흥동 2의 64']
# 판례일련번호: 118641, 찾은 주소: ['중구 서소문동 37']
# 판례일련번호: 118898, 찾은 주소: ['종로구 관훈동 151의 8']
# 판례일련번호: 119228, 찾은 주소: ['영등포구 여의도동 1']
# 판례일련번호: 119305, 찾은 주소: ['서초구 양재동 249의 14']
# 판례일련번호: 119564, 찾은 주소: ['마포구 용강동 50의 1']
# 판례일련번호: 119656, 찾은 주소: ['영등포구 당산동 1가', '영등포구 당산동 1가', '영등포구 당산동 1가']
# 판례일련번호: 120118, 찾은 주소: ['남동구 남촌동 622의 10']
# 판례일련번호: 120572, 찾은 주소: ['원미구 상동 464의 4']
# 판례일련번호: 120787, 찾은 주소: ['종로구 구기동 139', '종로구 구기동 139']
# 판례일련번호: 120796, 찾은 주소: ['팔달구 매탄동 198의 51']
# 판례일련번호: 120798, 찾은 주소: ['중구 중앙동 5가']
# 판례일련번호: 120802, 찾은 주소: ['도봉구 창동 45']
# 판례일련번호: 121059, 찾은 주소: ['관악구 신림동 507의 23', '관악구 신림동 507의 23']
# 판례일련번호: 126280, 찾은 주소: ['수성구 지산동 751-3']
# 판례일련번호: 128019, 찾은 주소: ['노원구 공릉동 471-11']
# 판례일련번호: 129611, 찾은 주소: ['종로구 궁정동 50']
# 판례일련번호: 129716, 찾은 주소: ['남동구 간석동 754의 3']
# 판례일련번호: 130664, 찾은 주소: ['중구 운서동 2851']
# 판례일련번호: 130701, 찾은 주소: ['구로구 가리봉동 97-10']
# 판례일련번호: 132239, 찾은 주소: ['연수구 동춘동 812']
# 판례일련번호: 133490, 찾은 주소: ['팔달구 화성동 115-5']
# 판례일련번호: 135900, 찾은 주소: ['영등포구 영등포동2가', '영등포구 영등포동2가', '영등포구 영등포동2가']
# 판례일련번호: 138579, 찾은 주소: ['중구 보수동2가']
# 판례일련번호: 140328, 찾은 주소: ['북구 구암동 682-1']
# 판례일련번호: 141561, 찾은 주소: ['덕양구 화정동 996-2']
# 판례일련번호: 141562, 찾은 주소: ['서초구 방배동 445-5']
# 판례일련번호: 141563, 찾은 주소: ['부산진구 부전동 260-1']
# 판례일련번호: 141564, 찾은 주소: ['상당구 용담동 173-9']
# 판례일련번호: 141752, 찾은 주소: ['구로구 오류동 4']
# 판례일련번호: 142098, 찾은 주소: ['덕양구 원당동 672-1']
# 판례일련번호: 143200, 찾은 주소: ['동작구 흑석동 10']
# 판례일련번호: 146581, 찾은 주소: ['강남구 신사동 528']
# 판례일련번호: 147263, 찾은 주소: ['관악구 봉천동 1712', '관악구 봉천동 1712']
# 판례일련번호: 148761, 찾은 주소: ['서대문구 홍제동 299-12']
# 판례일련번호: 149913, 찾은 주소: ['분당구 구미동 175']
# 판례일련번호: 150992, 찾은 주소: ['부평구 십정동 402-35']
# 판례일련번호: 153092, 찾은 주소: ['강북구 미아동 71-6', '강북구 미아동 71-6']
# 판례일련번호: 157314, 찾은 주소: ['분당구 운중동 960', '분당구 판교동 526-3']
# 판례일련번호: 158777, 찾은 주소: ['북구 화명동 2306', '북구 만덕동 823-8']
# 판례일련번호: 159900, 찾은 주소: ['중구 회현동 1가']
# 판례일련번호: 159944, 찾은 주소: ['완산구 삼천동 1가']
# 판례일련번호: 160428, 찾은 주소: ['동안구 호계동 1054-6']
# 판례일련번호: 160713, 찾은 주소: ['일산서구 탄현동 439']
# 판례일련번호: 161834, 찾은 주소: ['덕양구 화정동 952']
# 판례일련번호: 163583, 찾은 주소: ['원미구 중동 1173']
# 판례일련번호: 168194, 찾은 주소: ['종로구 명동2가']
# 판례일련번호: 169491, 찾은 주소: ['처인구 고림동 191-6']
# 판례일련번호: 170891, 찾은 주소: ['강북구 우이동 568-7']
# 판례일련번호: 171753, 찾은 주소: ['광산구 신가동 1055']
# 판례일련번호: 171945, 찾은 주소: ['대덕구 오정동 133']
# 판례일련번호: 177901, 찾은 주소: ['송파구 신천동 7']
# 판례일련번호: 189725, 찾은 주소: ['구로구 가리봉동 60의 29']
# 판례일련번호: 190001, 찾은 주소: ['광진구 광장동 427']
# 판례일련번호: 190004, 찾은 주소: ['서대문구 창천동 53-50', '서대문구 창천동 30-336', '서대문구 창천동 30-11', '서대문구 창천동 30의 1', '서대문구 창천동 30의 1', '서대문구 창천동 30의 1', '서대문구 창천동 30의 1']
# 판례일련번호: 190089, 찾은 주소: ['서구 둔산동 1478']
# 판례일련번호: 190215, 찾은 주소: ['광산구 안청동 738의 5']
# 판례일련번호: 190216, 찾은 주소: ['중구 무교동 45']
# 판례일련번호: 190217, 찾은 주소: ['부산진구 부전동 503의 15']
# 판례일련번호: 190221, 찾은 주소: ['중구 항동 7가']
# 판례일련번호: 190244, 찾은 주소: ['광진구 자양동 680']
# 판례일련번호: 190260, 찾은 주소: ['송파구 잠실동 2', '송파구 잠실동 2']
# 판례일련번호: 190272, 찾은 주소: ['유성구 가정동 35', '유성구 가정동 35']
# 판례일련번호: 191909, 찾은 주소: ['종로구 연지동 136-74']
# 판례일련번호: 191912, 찾은 주소: ['동구 대림동 601']
# 판례일련번호: 191936, 찾은 주소: ['원미구 중동 883']
# 판례일련번호: 192088, 찾은 주소: ['영등포구 문래동 4가']
# 판례일련번호: 192874, 찾은 주소: ['남구 주월동 1205의 9']
# 판례일련번호: 209163, 찾은 주소: ['중랑구 신내동 449']
# 판례일련번호: 209239, 찾은 주소: ['유성구 원내동 306-17']
# 판례일련번호: 211245, 찾은 주소: ['송파구 송파동 110의 8']
# 판례일련번호: 212539, 찾은 주소: ['종로구 관훈동 21']
# 판례일련번호: 219971, 찾은 주소: ['남구 학익동 480의 13']
# 판례일련번호: 221503, 찾은 주소: ['강서구 가양동 52의 1']
# 판례일련번호: 222039, 찾은 주소: ['송파구 잠실본동 184의 5']
# 판례일련번호: 222063, 찾은 주소: ['광진구 구의동 234의 10']
# 판례일련번호: 222071, 찾은 주소: ['금천구 독산본동 958의 59']
# 판례일련번호: 222119, 찾은 주소: ['영등포구 당산동 4가', '영등포구 당산동 4가', '부평구 청천동 200', '부평구 청천동 200']
# 판례일련번호: 222921, 찾은 주소: ['송파구 잠실동 19']
# 판례일련번호: 222943, 찾은 주소: ['성동구 성수동 2가']
# 판례일련번호: 223045, 찾은 주소: ['강남구 역삼동 815', '중구 서소문동 39의 1']
# 판례일련번호: 223089, 찾은 주소: ['금정구 서동 297의 439']
# 판례일련번호: 223105, 찾은 주소: ['중구 장충동 2가']
# 판례일련번호: 223127, 찾은 주소: ['대덕구 대화동 16의 98']
# 판례일련번호: 223297, 찾은 주소: ['중구 청량리 5가', '중구 청량리 5가']
# 판례일련번호: 224099, 찾은 주소: ['남동구 고잔동 512-12']
# 판례일련번호: 224103, 찾은 주소: ['용산구 동부이촌동 160']
# 판례일련번호: 227285, 찾은 주소: ['중구 중앙동 50의 7', '동구 범일동 830의 18']
# 판례일련번호: 227427, 찾은 주소: ['강남구 청담동 79의 5']
# 판례일련번호: 227431, 찾은 주소: ['구로구 신도림동 460의 26', '중구 봉래동 2가', '구로구 신도림동 460의 26']
# 판례일련번호: 227443, 찾은 주소: ['강남구 논현동 141']
# 판례일련번호: 227503, 찾은 주소: ['서대문구 신촌동 134']
# 판례일련번호: 227515, 찾은 주소: ['동구 중동 76의 4']
# 판례일련번호: 227533, 찾은 주소: ['송파구 석촌동 213']
# 판례일련번호: 227537, 찾은 주소: ['중구 명동 2가']
# 판례일련번호: 227575, 찾은 주소: ['은평구 갈현동 392']
# 판례일련번호: 227591, 찾은 주소: ['강서구 개화동 435']
# 판례일련번호: 227651, 찾은 주소: ['해운대구 우동 1108의 96']
# 판례일련번호: 227675, 찾은 주소: ['송파구 가락동 600', '강동구 길동 445']
# 판례일련번호: 227677, 찾은 주소: ['중구 견지동 87의 1', '종로구 견지동 87의 1']
# 판례일련번호: 227681, 찾은 주소: ['강남구 일원동 690의 1']
# 판례일련번호: 227985, 찾은 주소: ['은평구 갈현동 382', '은평구 갈현동 382', '은평구 갈현동 520-35']
# 판례일련번호: 228051, 찾은 주소: ['해운대구 중동 1360', '해운대구 중동 1360']
# 판례일련번호: 228055, 찾은 주소: ['북구 연암동 298-4']
# 판례일련번호: 228669, 찾은 주소: ['영등포구 여의도동 45의15']
# 판례일련번호: 228727, 찾은 주소: ['강남구 압구정동 224의11', '서초구 반포동 398의2']
# 판례일련번호: 228957, 찾은 주소: ['중구 명동 2가']
# 판례일련번호: 229241, 찾은 주소: ['중구 신흥동 2가']
# 판례일련번호: 231355, 찾은 주소: ['도봉구 번동 463의 43', '도봉구 수유동 175의6']

# %%
# 동이나 리로 시작하고, 상세 주소에서 순서대로 출력
import pandas as pd
import re

def find_korean_addresses(text):
    """
    주어진 텍스트에서 한국 주소 형식에 맞는 문자열을 찾습니다.

    :param text: 검색할 전체 텍스트
    :return: 찾은 주소 목록
    """
    # 동 이나 리부터 시작하고, 마지막에 '가' 또는 '의 숫자'를 포함하는 주소 패턴
    address_pattern = r'([가-힣]{1,2}(?:동|리)\s?\d+(?:-\d+)?(?:가|의\s?\d+)?)'
    text = str(text)
    found_addresses = re.findall(address_pattern, text)
    return found_addresses

def extract_addresses_from_csv(file_path):
    """
    CSV 파일에서 판례일련번호와 판례내용을 읽고, 각 텍스트 내에서 한국 주소를 찾아 판례일련번호와 연결합니다.

    :param file_path: CSV 파일의 경로
    :return: 판례일련번호와 찾은 주소 목록
    """
    df = pd.read_csv(file_path)
    df['Found_Addresses'] = df['판례내용'].apply(find_korean_addresses)

    return df[df['Found_Addresses'].map(lambda d: len(d) > 0)][['판례일련번호', 'Found_Addresses']]

# CSV 파일 경로
csv_file_path = '/content/비실명화_형사.csv'  # 여기에 실제 파일 경로를 입력하세요.

# CSV 파일에서 주소 추출 및 판례일련번호와 연결
address_data = extract_addresses_from_csv(csv_file_path)

# 결과 출력
for index, row in address_data.iterrows():
    print(f"판례일련번호: {row['판례일련번호']}, 찾은 주소: {row['Found_Addresses']}")
# Out:
# 판례일련번호: 64477, 찾은 주소: ['신곡동 679']
# 판례일련번호: 64832, 찾은 주소: ['수산리 167-1', '수산리 167', '수산리 167']
# 판례일련번호: 65128, 찾은 주소: ['석봉동 177의 7']
# 판례일련번호: 65129, 찾은 주소: ['율정동 281', '율정동 2의 16']
# 판례일련번호: 65301, 찾은 주소: ['삼바리 1', '삼프리 1', '다리 1', '사고리 150']
# 판례일련번호: 67163, 찾은 주소: ['창촌리 53-3', '남산리 1225', '창촌리 666-5', '창촌리 22', '창촌리 698-1']
# 판례일련번호: 67223, 찾은 주소: ['칠암동 90']
# 판례일련번호: 67317, 찾은 주소: ['소문동 120-33']
# 판례일련번호: 67362, 찾은 주소: ['부평동 549의 38']
# 판례일련번호: 67482, 찾은 주소: ['고색동 886', '고색동 886-11', '고색동 886-14']
# 판례일련번호: 67497, 찾은 주소: ['평동 151']
# 판례일련번호: 67501, 찾은 주소: ['의도동 63']
# 판례일련번호: 67698, 찾은 주소: ['경원동 3가']
# 판례일련번호: 67720, 찾은 주소: ['원짜리 3']
# 판례일련번호: 67723, 찾은 주소: ['덕풍동 378-7']
# 판례일련번호: 67752, 찾은 주소: ['비동 301', '기산동 140-25']
# 판례일련번호: 67753, 찾은 주소: ['평원동 349-1']
# 판례일련번호: 67758, 찾은 주소: ['용담리 344', '용담리 172', '광치동 548-3', '광치동 548-3']
# 판례일련번호: 67796, 찾은 주소: ['논현동 63-9']
# 판례일련번호: 67826, 찾은 주소: ['권리 80', '권리 80']
# 판례일련번호: 67872, 찾은 주소: ['노동 3', '노동 3', '노동 3', '노동 3']
# 판례일련번호: 68000, 찾은 주소: ['짜리 6']
# 판례일련번호: 68103, 찾은 주소: ['의도동 23-2']
# 판례일련번호: 68105, 찾은 주소: ['금산리 2']
# 판례일련번호: 68442, 찾은 주소: ['달리 2002']
# 판례일련번호: 68715, 찾은 주소: ['사동 2']
# 판례일련번호: 68795, 찾은 주소: ['달리 2']
# 판례일련번호: 69011, 찾은 주소: ['화평동 66', '송현동 66의 292', '주안동 197의 20']
# 판례일련번호: 69087, 찾은 주소: ['정자동 6']
# 판례일련번호: 69181, 찾은 주소: ['화정동 1051', '화정동 1051']
# 판례일련번호: 69182, 찾은 주소: ['상천리 362-1']
# 판례일련번호: 69284, 찾은 주소: ['대연동 243-23']
# 판례일련번호: 69427, 찾은 주소: ['화양동 111의 102']
# 판례일련번호: 69528, 찾은 주소: ['선화동 21-13', '선화동 21-13', '선화동 21-13', '선화동 21-13', '선화동 21-13', '선화동 21-13']
# 판례일련번호: 69529, 찾은 주소: ['유금리 1020의 2']
# 판례일련번호: 69530, 찾은 주소: ['봉익동 23', '봉익동 23']
# 판례일련번호: 69562, 찾은 주소: ['천호동 454-2', '천호동 454-2', '등포동 434-5']
# 판례일련번호: 69563, 찾은 주소: ['역삼동 676', '역삼동 676']
# 판례일련번호: 69564, 찾은 주소: ['송정동 79-2', '서초동 1624-4']
# 판례일련번호: 69565, 찾은 주소: ['쌍용동 567']
# 판례일련번호: 69591, 찾은 주소: ['관철동 10-2']
# 판례일련번호: 69617, 찾은 주소: ['봉천동 874-9']
# 판례일련번호: 69634, 찾은 주소: ['인후동2가']
# 판례일련번호: 69699, 찾은 주소: ['당산동 3가']
# 판례일련번호: 69703, 찾은 주소: ['삼성동 44-10']
# 판례일련번호: 69704, 찾은 주소: ['중동 25-3', '포중동1']
# 판례일련번호: 69754, 찾은 주소: ['관음리 549-10']
# 판례일련번호: 69756, 찾은 주소: ['창소리 161', '궁동 213-21']
# 판례일련번호: 69787, 찾은 주소: ['영창리 579-3', '회성동 233-7']
# 판례일련번호: 69808, 찾은 주소: ['삼성동 142-43']
# 판례일련번호: 69810, 찾은 주소: ['범어동 33-2', '명동 2가', '평리동 655-15']
# 판례일련번호: 69811, 찾은 주소: ['논현동 446의 5']
# 판례일련번호: 69812, 찾은 주소: ['운암동 154-60', '대의동 58']
# 판례일련번호: 69813, 찾은 주소: ['막걸리 1', '막걸리 1', '막걸리 1', '막걸리 1']
# 판례일련번호: 69833, 찾은 주소: ['신천동 7-19', '덕소리 95']
# 판례일련번호: 69859, 찾은 주소: ['수기동 23-2']
# 판례일련번호: 69860, 찾은 주소: ['석촌동 273-5', '석촌동 273의 5']
# 판례일련번호: 69862, 찾은 주소: ['우아동 3가']
# 판례일련번호: 69881, 찾은 주소: ['월산동 344']
# 판례일련번호: 69883, 찾은 주소: ['역삼동 702-10']
# 판례일련번호: 69884, 찾은 주소: ['이원리 339']
# 판례일련번호: 69906, 찾은 주소: ['동선동 1가', '동선동 92-7', '동선동 1가', '동선동 1가']
# 판례일련번호: 69908, 찾은 주소: ['성남리 943-4', '성남리 943']
# 판례일련번호: 69928, 찾은 주소: ['한남동 737-28']
# 판례일련번호: 69929, 찾은 주소: ['송암리 570-3', '송암리 570-3']
# 판례일련번호: 69933, 찾은 주소: ['중앙동 2', '서초동 1675-1']
# 판례일련번호: 69934, 찾은 주소: ['마장동 507-5']
# 판례일련번호: 69935, 찾은 주소: ['황학동 274', '북성동 1가', '마포동 230-16', '등포동 3가', '머리 1', '이문동 258-39', '창천동 13-52']
# 판례일련번호: 69949, 찾은 주소: ['소촌동 1-4', '소촌동 1-4']
# 판례일련번호: 69950, 찾은 주소: ['민락동 179-7']
# 판례일련번호: 69952, 찾은 주소: ['송천동2가', '송천동2가']
# 판례일련번호: 69973, 찾은 주소: ['의림동 3-3']
# 판례일련번호: 69974, 찾은 주소: ['역삼동 678-39', '논현동 126-5', '삼성동 157-8', '오금동 162', '청담동 132-19', '오금동 162', '석현리 352-1', '청담동 132-19', '석현리 352-1', '매산리 584-4', '대현동 101-7', '석현리 352의 1', '달리 3', '석현리 352-1', '석현리 352-1', '석현리 352-1']
# 판례일련번호: 69999, 찾은 주소: ['신정동 1018의 14', '장짐리 273의 1']
# 판례일련번호: 70001, 찾은 주소: ['지산동 761-10']
# 판례일련번호: 70002, 찾은 주소: ['주안동 982의 1', '만수동 109의 382', '주안동 106의 6']
# 판례일련번호: 70026, 찾은 주소: ['대신동3가']
# 판례일련번호: 70027, 찾은 주소: ['금오동 475-1', '금오동 475-1', '금오동 475-1']
# 판례일련번호: 70048, 찾은 주소: ['인후동 1가', '인후동 1가']
# 판례일련번호: 70073, 찾은 주소: ['논현동 70-6', '장안동 414-6']
# 판례일련번호: 70074, 찾은 주소: ['백운동 650의 8']
# 판례일련번호: 70075, 찾은 주소: ['모전리 35', '용수리 1021-14', '모전리 35', '모전리 35', '북정동 552의 2']
# 판례일련번호: 70096, 찾은 주소: ['명일동 112', '명일동 327-6', '명일동 112', '명일동 327-24', '명일동 112', '명일동 327-6', '명일동 112', '명일동 327-6', '명일동 327-24']
# 판례일련번호: 70097, 찾은 주소: ['수정동 625-33']
# 판례일련번호: 70102, 찾은 주소: ['문흥동 160']
# 판례일련번호: 70104, 찾은 주소: ['구정동 486']
# 판례일련번호: 70130, 찾은 주소: ['포체리 15']
# 판례일련번호: 70152, 찾은 주소: ['이연리 451-3', '이연리 451-3']
# 판례일련번호: 70155, 찾은 주소: ['가락동 600', '공동 10', '공동 10']
# 판례일련번호: 70157, 찾은 주소: ['황학동 688']
# 판례일련번호: 70188, 찾은 주소: ['중흥동 260-3', '에이동 408', '황금동 200']
# 판례일련번호: 70213, 찾은 주소: ['갈월동 98']
# 판례일련번호: 70215, 찾은 주소: ['대의동 58']
# 판례일련번호: 70377, 찾은 주소: ['범물동 1336']
# 판례일련번호: 70410, 찾은 주소: ['노동 3', '노동3']
# 판례일련번호: 70590, 찾은 주소: ['범어동 45-37']
# 판례일련번호: 70674, 찾은 주소: ['고잔동 512-12']
# 판례일련번호: 70675, 찾은 주소: ['용강동 38의 1']
# 판례일련번호: 70693, 찾은 주소: ['산성리 319-3', '산성리 319-3']
# 판례일련번호: 70759, 찾은 주소: ['이촌동 160']
# 판례일련번호: 70783, 찾은 주소: ['가좌동 292-17']
# 판례일련번호: 70812, 찾은 주소: ['명륜동 459', '명륜동 459']
# 판례일련번호: 70813, 찾은 주소: ['성남동 110-5']
# 판례일련번호: 70816, 찾은 주소: ['용강동 51-8']
# 판례일련번호: 70822, 찾은 주소: ['고잔동 641-6']
# 판례일련번호: 70824, 찾은 주소: ['삼성동 141', '달리 5']
# 판례일련번호: 70848, 찾은 주소: ['수색동 17-9', '가동 402']
# 판례일련번호: 70850, 찾은 주소: ['구월동 1280의 3']
# 판례일련번호: 70885, 찾은 주소: ['분평동 1224', '분평동 1224', '분평동 1224']
# 판례일련번호: 70906, 찾은 주소: ['신내동 646']
# 판례일련번호: 70907, 찾은 주소: ['해선리 317-9']
# 판례일련번호: 70909, 찾은 주소: ['홍제동 462']
# 판례일련번호: 70981, 찾은 주소: ['네거리 425', '네거리 425']
# 판례일련번호: 71043, 찾은 주소: ['연산동 584-1']
# 판례일련번호: 71044, 찾은 주소: ['대사동 640']
# 판례일련번호: 71067, 찾은 주소: ['소리 2']
# 판례일련번호: 71071, 찾은 주소: ['문래동3가']
# 판례일련번호: 71101, 찾은 주소: ['산저리 280-1']
# 판례일련번호: 71125, 찾은 주소: ['가천리 818']
# 판례일련번호: 71171, 찾은 주소: ['종암동 3의 142']
# 판례일련번호: 71247, 찾은 주소: ['동대동 1865']
# 판례일련번호: 71248, 찾은 주소: ['고잔동 437의 4', '고잔동 537의 4']
# 판례일련번호: 71534, 찾은 주소: ['달리 1998']
# 판례일련번호: 71536, 찾은 주소: ['화서동 650']
# 판례일련번호: 71564, 찾은 주소: ['구잠리 222', '읍내리 746']
# 판례일련번호: 71565, 찾은 주소: ['대원동 279-1']
# 판례일련번호: 71567, 찾은 주소: ['아현동 176-116', '아현동 176-116', '아현동 176-116']
# 판례일련번호: 71591, 찾은 주소: ['용두동 188']
# 판례일련번호: 76083, 찾은 주소: ['광복동 2가']
# 판례일련번호: 76090, 찾은 주소: ['서정동 239']
# 판례일련번호: 76095, 찾은 주소: ['인후동 1가']
# 판례일련번호: 76177, 찾은 주소: ['돈짜리 1', '돈짜리 1']
# 판례일련번호: 76179, 찾은 주소: ['덩어리 2', '덩어리 1']
# 판례일련번호: 76184, 찾은 주소: ['같은동 624의 9']
# 판례일련번호: 76187, 찾은 주소: ['달성동 294']
# 판례일련번호: 76262, 찾은 주소: ['시흥동 985-1', '박달동 68', '시흥동 985-1']
# 판례일련번호: 76263, 찾은 주소: ['교동 114', '같은동 119', '교동 119']
# 판례일련번호: 76269, 찾은 주소: ['가락동 321', '가락동 321', '옥인동 13의 1', '삼정동 272', '가락동 321', '가락동 321', '가락동 321', '원짜리 1', '원짜리 1', '원짜리 1', '구의동 230의 1']
# 판례일련번호: 76273, 찾은 주소: ['민락동 168의 13']
# 판례일련번호: 76275, 찾은 주소: ['대명동 82의 5']
# 판례일련번호: 76277, 찾은 주소: ['호원리 48']
# 판례일련번호: 76278, 찾은 주소: ['구산동 8의 3', '회현동 1가', '중학동 4']
# 판례일련번호: 76366, 찾은 주소: ['같은동 526의 10']
# 판례일련번호: 76439, 찾은 주소: ['방배동 915의 2', '가동 101']
# 판례일련번호: 76440, 찾은 주소: ['달리 1']
# 판례일련번호: 76441, 찾은 주소: ['내동1']
# 판례일련번호: 76454, 찾은 주소: ['공단동 2', '공당동 2', '공단동 2']
# 판례일련번호: 76455, 찾은 주소: ['같은리 154']
# 판례일련번호: 76536, 찾은 주소: ['장당동 390의 1', '이충동 459']
# 판례일련번호: 76541, 찾은 주소: ['소사동 93의 19', '소사동 93의 19']
# 판례일련번호: 76546, 찾은 주소: ['양평동 1가']
# 판례일련번호: 76548, 찾은 주소: ['신림동 112의 39', '신풍동 305의 2']
# 판례일련번호: 76549, 찾은 주소: ['논현동 199', '명주동 4의 1', '논현동 199', '명주동 4의 1']
# 판례일련번호: 76623, 찾은 주소: ['하방리 177']
# 판례일련번호: 76626, 찾은 주소: ['고산동 107']
# 판례일련번호: 76688, 찾은 주소: ['역삼동 736의 16']
# 판례일련번호: 76689, 찾은 주소: ['대청동 2가', '대청동 1가']
# 판례일련번호: 76690, 찾은 주소: ['부짜리 1']
# 판례일련번호: 76694, 찾은 주소: ['풍납동 281', '현동 19']
# 판례일련번호: 76699, 찾은 주소: ['같은리 154']
# 판례일련번호: 76700, 찾은 주소: ['용당리 242']
# 판례일련번호: 76706, 찾은 주소: ['같은동 386의 2', '같은동 386의 2']
# 판례일련번호: 76712, 찾은 주소: ['소사동 294의 64']
# 판례일련번호: 76715, 찾은 주소: ['삼성동 159']
# 판례일련번호: 76716, 찾은 주소: ['같은동 76-1']
# 판례일련번호: 76717, 찾은 주소: ['원수동 1']
# 판례일련번호: 76795, 찾은 주소: ['돈짜리 1']
# 판례일련번호: 76888, 찾은 주소: ['원짜리 30']
# 판례일련번호: 76978, 찾은 주소: ['서초동 1303의 35']
# 판례일련번호: 76985, 찾은 주소: ['만리동 126']
# 판례일련번호: 77089, 찾은 주소: ['상남동 136']
# 판례일련번호: 77093, 찾은 주소: ['해안동 2가']
# 판례일련번호: 77096, 찾은 주소: ['효성동 401의 1']
# 판례일련번호: 77101, 찾은 주소: ['수창동 40의 5', '칠성동 2가', '삼덕동 2가']
# 판례일련번호: 79089, 찾은 주소: ['사당동 2-2']
# 판례일련번호: 79090, 찾은 주소: ['영주동 743의 80']
# 판례일련번호: 79178, 찾은 주소: ['노원동 3가']
# 판례일련번호: 79182, 찾은 주소: ['본동 1']
# 판례일련번호: 80155, 찾은 주소: ['달리 1999']
# 판례일련번호: 80617, 찾은 주소: ['장현리 17']
# 판례일련번호: 80713, 찾은 주소: ['역삼동 831']
# 판례일련번호: 80716, 찾은 주소: ['이천동 491의 59']
# 판례일련번호: 80753, 찾은 주소: ['수산리 217의 3']
# 판례일련번호: 80833, 찾은 주소: ['부민동 1가', '부민동 2가']
# 판례일련번호: 80869, 찾은 주소: ['주엽동 17']
# 판례일련번호: 80970, 찾은 주소: ['신길동 60의 4']
# 판례일련번호: 81012, 찾은 주소: ['소문동 14의 2']
# 판례일련번호: 81402, 찾은 주소: ['짜리 1']
# 판례일련번호: 81549, 찾은 주소: ['달리 4']
# 판례일련번호: 81776, 찾은 주소: ['탄현동 1249']
# 판례일련번호: 81894, 찾은 주소: ['항동7가']
# 판례일련번호: 81963, 찾은 주소: ['답십리 4']
# 판례일련번호: 82176, 찾은 주소: ['방배동 824']
# 판례일련번호: 82685, 찾은 주소: ['상동 361-28']
# 판례일련번호: 82739, 찾은 주소: ['서초동 1701-1']
# 판례일련번호: 82771, 찾은 주소: ['여월동 6-1']
# 판례일련번호: 82923, 찾은 주소: ['동부리 42']
# 판례일련번호: 82925, 찾은 주소: ['노동3']
# 판례일련번호: 82931, 찾은 주소: ['동빈동 1가']
# 판례일련번호: 83290, 찾은 주소: ['자양동 597-9']
# 판례일련번호: 83429, 찾은 주소: ['마동 23']
# 판례일련번호: 83570, 찾은 주소: ['범일동 830의 134']
# 판례일련번호: 83918, 찾은 주소: ['계산동 1083-7']
# 판례일련번호: 83921, 찾은 주소: ['동선동 1가']
# 판례일련번호: 83940, 찾은 주소: ['서현동 91']
# 판례일련번호: 84120, 찾은 주소: ['력짜리 10', '력짜리 5', '력짜리 2', '력짜리 5', '력짜리 10', '력짜리 5', '력짜리 10']
# 판례일련번호: 85037, 찾은 주소: ['효성동 515-9', '효성동 515-9']
# 판례일련번호: 85710, 찾은 주소: ['피쓰리 1']
# 판례일련번호: 85753, 찾은 주소: ['달리 3']
# 판례일련번호: 100175, 찾은 주소: ['터짜리 1']
# 판례일련번호: 100413, 찾은 주소: ['휘경동 34']
# 판례일련번호: 100461, 찾은 주소: ['중화동 331의 67']
# 판례일련번호: 100526, 찾은 주소: ['달리 1']
# 판례일련번호: 100583, 찾은 주소: ['평리 1']
# 판례일련번호: 100636, 찾은 주소: ['같은동 1']
# 판례일련번호: 101056, 찾은 주소: ['신림동 112의 39']
# 판례일련번호: 101113, 찾은 주소: ['같은동 584의 6', '같은동 584의7']
# 판례일련번호: 101363, 찾은 주소: ['용현동 42']
# 판례일련번호: 101439, 찾은 주소: ['구의동 234']
# 판례일련번호: 101500, 찾은 주소: ['같은동 379의 11']
# 판례일련번호: 101647, 찾은 주소: ['같은동 3가']
# 판례일련번호: 101763, 찾은 주소: ['부짜리 274', '부짜리 274', '부짜리 30', '부짜리 30']
# 판례일련번호: 101864, 찾은 주소: ['같은동 2가', '같은동 2가', '같은동 2가', '같은동 2가']
# 판례일련번호: 101898, 찾은 주소: ['덩어리 2', '덩어리 1']
# 판례일련번호: 102059, 찾은 주소: ['염리동 151']
# 판례일련번호: 102114, 찾은 주소: ['유리 1']
# 판례일련번호: 102173, 찾은 주소: ['제기동 857']
# 판례일련번호: 102308, 찾은 주소: ['달리 1']
# 판례일련번호: 102368, 찾은 주소: ['경동161-1']
# 판례일련번호: 102585, 찾은 주소: ['대신동 1942']
# 판례일련번호: 102588, 찾은 주소: ['삼일리 65의 3']
# 판례일련번호: 102736, 찾은 주소: ['대청동 1가']
# 판례일련번호: 103082, 찾은 주소: ['원짜리 1', '원짜리 1', '원짜리 2']
# 판례일련번호: 103795, 찾은 주소: ['노원동 3가']
# 판례일련번호: 103956, 찾은 주소: ['상평동 278']
# 판례일련번호: 104613, 찾은 주소: ['같은리 832']
# 판례일련번호: 105367, 찾은 주소: ['등포동 4가']
# 판례일련번호: 105421, 찾은 주소: ['위리 3']
# 판례일련번호: 105748, 찾은 주소: ['성내동 64의14']
# 판례일련번호: 106481, 찾은 주소: ['교동 280']
# 판례일련번호: 106627, 찾은 주소: ['노동 3']
# 판례일련번호: 107016, 찾은 주소: ['창동 749']
# 판례일련번호: 107343, 찾은 주소: ['술운동 2']
# 판례일련번호: 107351, 찾은 주소: ['소꼬리 20']
# 판례일련번호: 107766, 찾은 주소: ['노동 3', '노동 3']
# 판례일련번호: 107769, 찾은 주소: ['석교리 2']
# 판례일련번호: 109403, 찾은 주소: ['같은동 938의 1', '같은동 954의 1', '같은동 959', '같은동 938의 2']
# 판례일련번호: 109406, 찾은 주소: ['삼화동 10']
# 판례일련번호: 111349, 찾은 주소: ['달리 2']
# 판례일련번호: 111806, 찾은 주소: ['창포동 3가']
# 판례일련번호: 112162, 찾은 주소: ['달리 1990']
# 판례일련번호: 112700, 찾은 주소: ['다동 201']
# 판례일련번호: 112708, 찾은 주소: ['연리 5', '연리 12', '연리 12', '연리 5', '연리 12']
# 판례일련번호: 112838, 찾은 주소: ['밧데리 50']
# 판례일련번호: 112970, 찾은 주소: ['부평동 2가']
# 판례일련번호: 112974, 찾은 주소: ['평리 2']
# 판례일련번호: 113684, 찾은 주소: ['노동3']
# 판례일련번호: 113901, 찾은 주소: ['서천리 518']
# 판례일련번호: 114027, 찾은 주소: ['옆구리 1']
# 판례일련번호: 114671, 찾은 주소: ['짜리 120']
# 판례일련번호: 115951, 찾은 주소: ['신포동 2']
# 판례일련번호: 116290, 찾은 주소: ['병동 21']
# 판례일련번호: 116414, 찾은 주소: ['병동 11']
# 판례일련번호: 116655, 찾은 주소: ['반곡동 1602의 1']
# 판례일련번호: 116898, 찾은 주소: ['사파동 1']
# 판례일련번호: 116971, 찾은 주소: ['연리 5', '연리 12']
# 판례일련번호: 117690, 찾은 주소: ['생연동 400의 3']
# 판례일련번호: 117695, 찾은 주소: ['신천동 7의 13']
# 판례일련번호: 117795, 찾은 주소: ['용답동 233의 10']
# 판례일련번호: 118392, 찾은 주소: ['다동 503']
# 판례일련번호: 118395, 찾은 주소: ['에이동 103', '에이동 103']
# 판례일련번호: 118486, 찾은 주소: ['원동 21의6']
# 판례일련번호: 118565, 찾은 주소: ['신촌동 134']
# 판례일련번호: 118566, 찾은 주소: ['대흥동 2의 64']
# 판례일련번호: 118641, 찾은 주소: ['소문동 37']
# 판례일련번호: 118898, 찾은 주소: ['관훈동 151의 8']
# 판례일련번호: 119063, 찾은 주소: ['진동리 260의1']
# 판례일련번호: 119217, 찾은 주소: ['조합동 26']
# 판례일련번호: 119225, 찾은 주소: ['하안동 10', '하안동 10']
# 판례일련번호: 119228, 찾은 주소: ['의도동 1']
# 판례일련번호: 119305, 찾은 주소: ['양재동 249의 14']
# 판례일련번호: 119397, 찾은 주소: ['씨동 101', '씨동 101']
# 판례일련번호: 119564, 찾은 주소: ['용강동 50의 1']
# 판례일련번호: 119656, 찾은 주소: ['당산동 1가', '당산동 1가', '당산동 1가']
# 판례일련번호: 120118, 찾은 주소: ['남촌동 622의 10']
# 판례일련번호: 120572, 찾은 주소: ['상동 464의 4']
# 판례일련번호: 120787, 찾은 주소: ['구기동 139', '구기동 139']
# 판례일련번호: 120796, 찾은 주소: ['매탄동 198의 51']
# 판례일련번호: 120797, 찾은 주소: ['사활동 120', '사파동 52의 3']
# 판례일련번호: 120798, 찾은 주소: ['중앙동 5가']
# 판례일련번호: 120802, 찾은 주소: ['창동 45']
# 판례일련번호: 120933, 찾은 주소: ['달리 1996']
# 판례일련번호: 121059, 찾은 주소: ['신림동 507의 23', '신림동 507의 23']
# 판례일련번호: 121065, 찾은 주소: ['중앙동 4의 6', '중앙동 4의 6']
# 판례일련번호: 122289, 찾은 주소: ['거리 5']
# 판례일련번호: 123328, 찾은 주소: ['개동 92']
# 판례일련번호: 124839, 찾은 주소: ['막걸리 1', '우두동 2', '우두동 2']
# 판례일련번호: 125087, 찾은 주소: ['다대동 1541']
# 판례일련번호: 126212, 찾은 주소: ['달리 1']
# 판례일련번호: 126280, 찾은 주소: ['지산동 751-3']
# 판례일련번호: 126537, 찾은 주소: ['노동3', '노동3', '노동3', '노동3']
# 판례일련번호: 128019, 찾은 주소: ['공릉동 471-11']
# 판례일련번호: 129611, 찾은 주소: ['궁정동 50']
# 판례일련번호: 129716, 찾은 주소: ['간석동 754의 3']
# 판례일련번호: 129763, 찾은 주소: ['미리 10']
# 판례일련번호: 130664, 찾은 주소: ['운서동 2851']
# 판례일련번호: 130701, 찾은 주소: ['리봉동 97-10']
# 판례일련번호: 132239, 찾은 주소: ['동춘동 812']
# 판례일련번호: 133490, 찾은 주소: ['화성동 115-5']
# 판례일련번호: 134370, 찾은 주소: ['차라리 1']
# 판례일련번호: 135900, 찾은 주소: ['등포동2가', '등포동2가', '등포동2가']
# 판례일련번호: 138579, 찾은 주소: ['보수동2가']
# 판례일련번호: 139128, 찾은 주소: ['신부동 72-16']
# 판례일련번호: 139129, 찾은 주소: ['항아리 2', '항아리 3']
# 판례일련번호: 140328, 찾은 주소: ['구암동 682-1']
# 판례일련번호: 141561, 찾은 주소: ['화정동 996-2']
# 판례일련번호: 141562, 찾은 주소: ['방배동 445-5']
# 판례일련번호: 141563, 찾은 주소: ['부전동 260-1']
# 판례일련번호: 141564, 찾은 주소: ['용담동 173-9']
# 판례일련번호: 141752, 찾은 주소: ['오류동 4']
# 판례일련번호: 142028, 찾은 주소: ['개동 11']
# 판례일련번호: 142029, 찾은 주소: ['삼계동 117', '서상동 27-24', '동상동 727-1', '내동 1131-2', '삼계동 117', '삼계동 117']
# 판례일련번호: 142098, 찾은 주소: ['원당동 672-1']
# 판례일련번호: 142485, 찾은 주소: ['칠성리 603-1']
# 판례일련번호: 142810, 찾은 주소: ['원짜리 1', '원짜리 1']
# 판례일련번호: 142815, 찾은 주소: ['달리 2005']
# 판례일련번호: 143198, 찾은 주소: ['백전리 135', '백전리 135']
# 판례일련번호: 143200, 찾은 주소: ['흑석동 10']
# 판례일련번호: 143201, 찾은 주소: ['신양리 18-2', '신양리 18-2']
# 판례일련번호: 143585, 찾은 주소: ['두촌리 195-8', '두촌리 195-8']
# 판례일련번호: 143652, 찾은 주소: ['용강동 1228-3', '황성동 1053-71']
# 판례일련번호: 144204, 찾은 주소: ['화동 3']
# 판례일련번호: 145535, 찾은 주소: ['막걸리 2']
# 판례일련번호: 145863, 찾은 주소: ['초정리 708']
# 판례일련번호: 146491, 찾은 주소: ['막걸리 1']
# 판례일련번호: 146581, 찾은 주소: ['신사동 528']
# 판례일련번호: 147263, 찾은 주소: ['봉천동 1712', '봉천동 1712']
# 판례일련번호: 148475, 찾은 주소: ['연리 1']
# 판례일련번호: 148761, 찾은 주소: ['홍제동 299-12']
# 판례일련번호: 148929, 찾은 주소: ['인서리 475-16']
# 판례일련번호: 149913, 찾은 주소: ['구미동 175']
# 판례일련번호: 150992, 찾은 주소: ['십정동 402-35']
# 판례일련번호: 153092, 찾은 주소: ['미아동 71-6', '미아동 71-6']
# 판례일련번호: 157314, 찾은 주소: ['운중동 960', '판교동 526-3']
# 판례일련번호: 158765, 찾은 주소: ['달리 2005']
# 판례일련번호: 158767, 찾은 주소: ['우두동 2']
# 판례일련번호: 158777, 찾은 주소: ['쇠고리 3', '화명동 2306', '삼정동 591-2', '만덕동 823-8']
# 판례일련번호: 159281, 찾은 주소: ['매곡리 472']
# 판례일련번호: 159900, 찾은 주소: ['회현동 1가']
# 판례일련번호: 159944, 찾은 주소: ['삼천동 1가']
# 판례일련번호: 160428, 찾은 주소: ['호계동 1054-6']
# 판례일련번호: 160713, 찾은 주소: ['탄현동 439']
# 판례일련번호: 161431, 찾은 주소: ['본리리 408']
# 판례일련번호: 161834, 찾은 주소: ['화정동 952']
# 판례일련번호: 163547, 찾은 주소: ['민락동 576']
# 판례일련번호: 163583, 찾은 주소: ['중동 1173']
# 판례일련번호: 164796, 찾은 주소: ['달리 6']
# 판례일련번호: 168194, 찾은 주소: ['명동2가']
# 판례일련번호: 169491, 찾은 주소: ['고림동 191-6', '유방동 733-1', '대대리 488', '운학동 327', '대대리 488']
# 판례일련번호: 170703, 찾은 주소: ['달리 2008']
# 판례일련번호: 170882, 찾은 주소: ['달리 19']
# 판례일련번호: 170891, 찾은 주소: ['우이동 568-7']
# 판례일련번호: 171753, 찾은 주소: ['신가동 1055']
# 판례일련번호: 171945, 찾은 주소: ['오정동 133']
# 판례일련번호: 172309, 찾은 주소: ['달리 2010']
# 판례일련번호: 173194, 찾은 주소: ['달리 19']
# 판례일련번호: 175132, 찾은 주소: ['애아동 8']
# 판례일련번호: 175334, 찾은 주소: ['밸리 1909', '밸리 701']
# 판례일련번호: 175600, 찾은 주소: ['달리 2010']
# 판례일련번호: 177901, 찾은 주소: ['신천동 7']
# 판례일련번호: 179115, 찾은 주소: ['연리 2']
# 판례일련번호: 179265, 찾은 주소: ['인젤리2', '인젤리2']
# 판례일련번호: 182855, 찾은 주소: ['반거리 1']
# 판례일련번호: 182934, 찾은 주소: ['나동 4']
# 판례일련번호: 183318, 찾은 주소: ['관리2']
# 판례일련번호: 183573, 찾은 주소: ['귀고리 2']
# 판례일련번호: 183596, 찾은 주소: ['정금리 7']
# 판례일련번호: 183662, 찾은 주소: ['달리 2003']
# 판례일련번호: 183690, 찾은 주소: ['사무동 1']
# 판례일련번호: 184373, 찾은 주소: ['개동 103']
# 판례일련번호: 185093, 찾은 주소: ['달리 650']
# 판례일련번호: 187887, 찾은 주소: ['달리 1']
# 판례일련번호: 189162, 찾은 주소: ['수하리 114의 3']
# 판례일련번호: 189596, 찾은 주소: ['관리동 2']
# 판례일련번호: 189631, 찾은 주소: ['쏘가리 2']
# 판례일련번호: 189725, 찾은 주소: ['리봉동 60의 29']
# 판례일련번호: 189729, 찾은 주소: ['씨동 101']
# 판례일련번호: 189981, 찾은 주소: ['사동 126의2']
# 판례일련번호: 190001, 찾은 주소: ['광장동 427']
# 판례일련번호: 190004, 찾은 주소: ['창천동 53-50', '창천동 30-336', '창천동 30-11', '창천동 30의 1', '창천동 30의 1', '창천동 30의 1', '창천동 30의 1', '창천동 30의 1']
# 판례일련번호: 190007, 찾은 주소: ['달리 4']
# 판례일련번호: 190013, 찾은 주소: ['오관리 108']
# 판례일련번호: 190015, 찾은 주소: ['남리 366', '남리 366']
# 판례일련번호: 190053, 찾은 주소: ['성북동 15']
# 판례일련번호: 190082, 찾은 주소: ['짜리 6']
# 판례일련번호: 190088, 찾은 주소: ['노동3', '노동3']
# 판례일련번호: 190089, 찾은 주소: ['둔산동 1478']
# 판례일련번호: 190215, 찾은 주소: ['안청동 738의 5']
# 판례일련번호: 190216, 찾은 주소: ['운전리 25의 1', '무교동 45', '별양동 1의 23']
# 판례일련번호: 190217, 찾은 주소: ['부전동 503의 15']
# 판례일련번호: 190218, 찾은 주소: ['유천리 192']
# 판례일련번호: 190221, 찾은 주소: ['항동 7가']
# 판례일련번호: 190236, 찾은 주소: ['달리 18']
# 판례일련번호: 190244, 찾은 주소: ['자양동 680']
# 판례일련번호: 190259, 찾은 주소: ['짜리 200']
# 판례일련번호: 190260, 찾은 주소: ['잠실동 2', '잠실동 2']
# 판례일련번호: 190272, 찾은 주소: ['가정동 35', '가정동 35']
# 판례일련번호: 190294, 찾은 주소: ['태리 916']
# 판례일련번호: 191909, 찾은 주소: ['연지동 136-74']
# 판례일련번호: 191912, 찾은 주소: ['대림동 601']
# 판례일련번호: 191936, 찾은 주소: ['중동 883', '개동 100', '개동 1', '개동 930', '개동 480', '개동 148']
# 판례일련번호: 192088, 찾은 주소: ['문래동 4가']
# 판례일련번호: 192845, 찾은 주소: ['개동 627']
# 판례일련번호: 192862, 찾은 주소: ['대창리 872-1']
# 판례일련번호: 192865, 찾은 주소: ['외성리 317-23', '개동 440']
# 판례일련번호: 192874, 찾은 주소: ['주월동 1205의 9']
# 판례일련번호: 195374, 찾은 주소: ['달리 15']
# 판례일련번호: 199918, 찾은 주소: ['노동3']
# 판례일련번호: 203908, 찾은 주소: ['비동 690', '씨동 806', '디동 909', '이동 729', '에이동 759', '비동 706', '씨동 632', '디동 573', '이동 406', '에프동 474']
# 판례일련번호: 205666, 찾은 주소: ['뜬다리 2', '뜬다리 3']
# 판례일련번호: 209163, 찾은 주소: ['신내동 449']
# 판례일련번호: 209239, 찾은 주소: ['원내동 306-17']
# 판례일련번호: 211245, 찾은 주소: ['송파동 110의 8']
# 판례일련번호: 212539, 찾은 주소: ['관훈동 21']
# 판례일련번호: 215443, 찾은 주소: ['사거리 1']
# 판례일련번호: 215643, 찾은 주소: ['달리 2']
# 판례일련번호: 216381, 찾은 주소: ['노동3', '노동3', '노동 3']
# 판례일련번호: 216535, 찾은 주소: ['금호동 343-1']
# 판례일련번호: 216613, 찾은 주소: ['원동 359']
# 판례일련번호: 217781, 찾은 주소: ['노동3', '노동3']
# 판례일련번호: 219145, 찾은 주소: ['노동3']
# 판례일련번호: 219971, 찾은 주소: ['학익동 480의 13']
# 판례일련번호: 221503, 찾은 주소: ['가양동 52의 1']
# 판례일련번호: 221717, 찾은 주소: ['동바리 2', '동바리 2']
# 판례일련번호: 222039, 찾은 주소: ['실본동 184의 5']
# 판례일련번호: 222063, 찾은 주소: ['구의동 234의 10']
# 판례일련번호: 222071, 찾은 주소: ['산본동 958의 59']
# 판례일련번호: 222119, 찾은 주소: ['당산동 4가', '당산동 4가', '누산리 1047', '청천동 200', '청천동 200']
# 판례일련번호: 222155, 찾은 주소: ['보리 5', '보리 5', '보리 5', '보리 5']
# 판례일련번호: 222705, 찾은 주소: ['노동3']
# 판례일련번호: 222921, 찾은 주소: ['잠실동 19']
# 판례일련번호: 222943, 찾은 주소: ['성수동 2가']
# 판례일련번호: 222969, 찾은 주소: ['별양동 5', '별양동 5']
# 판례일련번호: 223045, 찾은 주소: ['역삼동 815', '소문동 39의 1']
# 판례일련번호: 223075, 찾은 주소: ['역리 678']
# 판례일련번호: 223089, 찾은 주소: ['서동 297의 439']
# 판례일련번호: 223097, 찾은 주소: ['원짜리 1', '원짜리 1', '십리동 1의 2']
# 판례일련번호: 223105, 찾은 주소: ['장충동 2가']
# 판례일련번호: 223127, 찾은 주소: ['대화동 16의 98']
# 판례일련번호: 223147, 찾은 주소: ['노동 3', '노동 3']
# 판례일련번호: 223181, 찾은 주소: ['문화동 739의 8', '문화동 739의 8']
# 판례일련번호: 223239, 찾은 주소: ['죽전리 877', '덕천리 69의 17', '덕천리 69의 17']
# 판례일련번호: 223293, 찾은 주소: ['돗자리 1']
# 판례일련번호: 223297, 찾은 주소: ['청량리 5가', '청량리 5가']
# 판례일련번호: 224099, 찾은 주소: ['고잔동 512-12']
# 판례일련번호: 224103, 찾은 주소: ['이촌동 160']
# 판례일련번호: 225987, 찾은 주소: ['애아동 3']
# 판례일련번호: 226477, 찾은 주소: ['노동3']
# 판례일련번호: 227285, 찾은 주소: ['중앙동 50의 7', '범일동 830의 18']
# 판례일련번호: 227427, 찾은 주소: ['청담동 79의 5']
# 판례일련번호: 227431, 찾은 주소: ['도림동 460의 26', '봉래동 2가', '도림동 460의 26']
# 판례일련번호: 227443, 찾은 주소: ['논현동 141']
# 판례일련번호: 227467, 찾은 주소: ['기동 3']
# 판례일련번호: 227503, 찾은 주소: ['신촌동 134']
# 판례일련번호: 227515, 찾은 주소: ['중동 76의 4']
# 판례일련번호: 227533, 찾은 주소: ['석촌동 213']
# 판례일련번호: 227537, 찾은 주소: ['명동 2가']
# 판례일련번호: 227575, 찾은 주소: ['갈현동 392']
# 판례일련번호: 227591, 찾은 주소: ['개화동 435']
# 판례일련번호: 227635, 찾은 주소: ['달리 20']
# 판례일련번호: 227649, 찾은 주소: ['터짜리 5', '안양동 817의 21']
# 판례일련번호: 227651, 찾은 주소: ['우동 1108의 96']
# 판례일련번호: 227659, 찾은 주소: ['본오동 312', '본오동 312', '본오동 312']
# 판례일련번호: 227675, 찾은 주소: ['가락동 600', '석촌동 285', '길동 445']
# 판례일련번호: 227677, 찾은 주소: ['견지동 87의 1', '견지동 87의 1']
# 판례일련번호: 227681, 찾은 주소: ['일원동 690의 1']
# 판례일련번호: 227985, 찾은 주소: ['갈현동 382', '갈현동 382', '갈현동 520-35']
# 판례일련번호: 228051, 찾은 주소: ['중동 1360', '중동 1360']
# 판례일련번호: 228055, 찾은 주소: ['연암동 298-4']
# 판례일련번호: 228579, 찾은 주소: ['괴안동 87의 14', '대야동 408', '대야동 408']
# 판례일련번호: 228637, 찾은 주소: ['문화동 109의2']
# 판례일련번호: 228669, 찾은 주소: ['신성리 427의13', '의도동 45의15']
# 판례일련번호: 228673, 찾은 주소: ['램짜리 10', '램짜리 100']
# 판례일련번호: 228679, 찾은 주소: ['램짜리 76', '램짜리 32', '램짜리 520', '램짜리 76', '램짜리 520', '램짜리 9', '램짜리 8', '램짜리 40', '램짜리 4', '램짜리 42', '램짜리 1', '램짜리 12', '램짜리 5', '램짜리 76', '램짜리 32', '램짜리 520', '램짜리 9', '램짜리 76', '램짜리 520', '램짜리 9', '램짜리 76', '램짜리 32', '램짜리 520', '램짜리 9', '램짜리 76', '램짜리 520', '램짜리 9']
# 판례일련번호: 228727, 찾은 주소: ['소공동 1', '구정동 224의11', '반포동 398의2']
# 판례일련번호: 228739, 찾은 주소: ['향소리 1046', '향소리 1046']
# 판례일련번호: 228753, 찾은 주소: ['달리 1990']
# 판례일련번호: 228957, 찾은 주소: ['명동 2가']
# 판례일련번호: 229241, 찾은 주소: ['신흥동 2가']
# 판례일련번호: 229269, 찾은 주소: ['팔곡동 410']
# 판례일련번호: 229271, 찾은 주소: ['달리 52']
# 판례일련번호: 229479, 찾은 주소: ['칠괴동 150의 3']
# 판례일련번호: 229759, 찾은 주소: ['달리 1994']
# 판례일련번호: 229999, 찾은 주소: ['막걸리 1']
# 판례일련번호: 230051, 찾은 주소: ['달리 1988']
# 판례일련번호: 231127, 찾은 주소: ['동부동 200', '당북동 109']
# 판례일련번호: 231233, 찾은 주소: ['부짜리 1']
# 판례일련번호: 231239, 찾은 주소: ['일산동 155']
# 판례일련번호: 231355, 찾은 주소: ['번동 463의 43', '수유동 169의56', '수유동 175의6']
# 판례일련번호: 231383, 찾은 주소: ['구기동 53의 2']
# 판례일련번호: 234535, 찾은 주소: ['노동3', '노동3', '노동3']
